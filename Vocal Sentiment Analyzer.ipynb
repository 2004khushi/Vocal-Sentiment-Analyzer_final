# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the Dataset

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
         break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
paths[:5]
# Out:
# ['/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_home_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_youth_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_near_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_search_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_pick_fear.wav']

# %%
labels[:5]
# Out:
# ['fear', 'fear', 'fear', 'fear', 'fear']

# %% [markdown]
# ## Create a Dataframe

# %%
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech label
# 0  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 1  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 2  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 3  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 4  /kaggle/input/toronto-emotional-speech-set-tes...  fear

# %%
df['label'].value_counts()
# Out:
# label
# fear       400
# angry      400
# disgust    400
# neutral    400
# sad        400
# ps         400
# happy      400
# Name: count, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(x='label', data=df)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def spectrogram(data, sr, emotion):
    plt.figure(figsize=(10, 4))
    plt.title(emotion, size=20)
    librosa.display.specshow(librosa.amplitude_to_db(np.abs(librosa.stft(data)), ref=np.max), sr=sr, x_axis='time', y_axis='log')
    plt.colorbar(format='%+2.0f dB')
    plt.show()

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Feature Extraction

# %%
def extract_mfcc(filename):
     y, sr = librosa.load(filename, duration=3, offset=0.5)
     mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
     return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-285.73727  ,   85.78295  ,   -2.1689117,   22.125532 ,
#         -14.757396 ,   11.051347 ,   12.412449 ,   -3.000262 ,
#           1.0844985,   11.078271 ,  -17.41966  ,   -8.093213 ,
#           6.5879736,   -4.2209525,   -9.15508  ,    3.5214796,
#         -13.186381 ,   14.078853 ,   19.66973  ,   22.725618 ,
#          32.57464  ,   16.325033 ,   -3.8427284,    0.8962967,
#         -11.239264 ,    6.653461 ,   -2.5883694,   -7.7140164,
#         -10.941657 ,   -2.4007552,   -5.2812862,    4.271157 ,
#         -11.202216 ,   -9.024621 ,   -3.666985 ,    4.8697433,
#          -1.6027987,    2.5600514,   11.454374 ,   11.233449 ],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-285.73727, 85.78295, -2.1689117, 22.125532, ...
# 1       [-348.34332, 35.193233, -3.8413284, 14.658875,...
# 2       [-340.11435, 53.796444, -14.267782, 20.884031,...
# 3       [-306.63422, 21.259708, -4.4110823, 6.4871554,...
# 4       [-344.7548, 46.329193, -24.171413, 19.392921, ...
#                               ...
# 2795    [-374.3952, 60.864998, 0.02505877, 8.431058, -...
# 2796    [-313.96478, 39.847843, -5.6493053, -3.8675754...
# 2797    [-357.54886, 77.88605, -15.224756, 2.194633, -...
# 2798    [-353.1474, 101.68391, -14.175897, -12.037376,...
# 2799    [-389.4595, 54.042767, 1.3469982, -1.4258989, ...
# Name: speech, Length: 2800, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %% [markdown]
# ## Create the LSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# 2024-03-26 10:55:06.978504: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 10:55:06.978649: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 10:55:07.153992: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 256)            │       264,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 305,799 (1.17 MB)
#  Trainable params: 305,799 (1.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.4403 - loss: 1.4817 - val_accuracy: 0.2286 - val_loss: 2.5547
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.8361 - loss: 0.4584 - val_accuracy: 0.1893 - val_loss: 2.2213
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.9076 - loss: 0.2862 - val_accuracy: 0.1643 - val_loss: 3.2305
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.9401 - loss: 0.1866 - val_accuracy: 0.3393 - val_loss: 2.4417
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.9506 - loss: 0.1473 - val_accuracy: 0.3679 - val_loss: 2.2715
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.9749 - loss: 0.0957 - val_accuracy: 0.3107 - val_loss: 3.4925
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.9570 - loss: 0.1447 - val_accuracy: 0.3107 - val_loss: 2.6507
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.9740 - loss: 0.0811 - val_accuracy: 0.4482 - val_loss: 2.0909
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9814 - loss: 0.0730 - val_accuracy: 0.2982 - val_loss: 3.0927
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.9646 - loss: 0.1149 - val_accuracy: 0.4429 - val_loss: 2.4378
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.9797 - loss: 0.0758 - val_accuracy: 0.4679 - val_loss: 2.2949
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.9812 - loss: 0.0648 - val_accuracy: 0.3643 - val_loss: 3.1997
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.9854 - loss: 0.0527 - val_accuracy: 0.3232 - val_loss: 2.8767
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9685 - loss: 0.0973 - val_accuracy: 0.3839 - val_loss: 3.2697
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.9875 - loss: 0.0417 - val_accuracy: 0.3143 - val_loss: 3.9956
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.9811 - loss: 0.0535 - val_accuracy: 0.4125 - val_loss: 2.2173
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9756 - loss: 0.0717 - val_accuracy: 0.5857 - val_loss: 2.3093
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9760 - loss: 0.0693 - val_accuracy: 0.3964 - val_loss: 3.2813
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9907 - loss: 0.0348 - val_accuracy: 0.4071 - val_loss: 3.3206
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9896 - loss: 0.0344 - val_accuracy: 0.4250 - val_loss: 3.4982
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9798 - loss: 0.0632 - val_accuracy: 0.3911 - val_loss: 2.9742
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9841 - loss: 0.0397 - val_accuracy: 0.4393 - val_loss: 3.5239
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.9955 - loss: 0.0185 - val_accuracy: 0.4857 - val_loss: 3.4742
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.9930 - loss: 0.0210 - val_accuracy: 0.3732 - val_loss: 3.1831
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.9851 - loss: 0.0481 - val_accuracy: 0.3804 - val_loss: 2.9280
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9874 - loss: 0.0261 - val_accuracy: 0.4339 - val_loss: 3.5861
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.9970 - loss: 0.0145 - val_accuracy: 0.4929 - val_loss: 3.6015
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.9970 - loss: 0.0130 - val_accuracy: 0.5321 - val_loss: 2.7668
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.9967 - loss: 0.0136 - val_accuracy: 0.4679 - val_loss: 3.7090
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.9938 - loss: 0.0326 - val_accuracy: 0.4018 - val_loss: 3.4592
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - accuracy: 0.9942 - loss: 0.0210 - val_accuracy: 0.3661 - val_loss: 4.7176
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.9886 - loss: 0.0386 - val_accuracy: 0.3643 - val_loss: 4.4090
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.9916 - loss: 0.0262 - val_accuracy: 0.4268 - val_loss: 3.6407
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 0.9772 - loss: 0.0815 - val_accuracy: 0.4625 - val_loss: 3.4564
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.9955 - loss: 0.0101 - val_accuracy: 0.6125 - val_loss: 2.4999
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - accuracy: 0.9936 - loss: 0.0136 - val_accuracy: 0.5018 - val_loss: 3.5493
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.9939 - loss: 0.0189 - val_accuracy: 0.3304 - val_loss: 4.6963
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.9633 - loss: 0.1002 - val_accuracy: 0.4464 - val_loss: 3.4650
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9959 - loss: 0.0198 - val_accuracy: 0.4732 - val_loss: 4.1225
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9985 - loss: 0.0073 - val_accuracy: 0.5071 - val_loss: 3.5607
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.9877 - loss: 0.0491 - val_accuracy: 0.4964 - val_loss: 3.4773
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.9972 - loss: 0.0128 - val_accuracy: 0.4732 - val_loss: 3.6743
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 0.9968 - loss: 0.0114 - val_accuracy: 0.5036 - val_loss: 4.1085
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.5089 - val_loss: 3.9696
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.4982 - val_loss: 4.2985
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 1.0000 - loss: 7.5531e-04 - val_accuracy: 0.5179 - val_loss: 4.1218
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.5054 - val_loss: 4.3750
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9995 - loss: 0.0016 - val_accuracy: 0.4839 - val_loss: 4.3239
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.5107 - val_loss: 4.3364
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.9997 - loss: 0.0010 - val_accuracy: 0.5536 - val_loss: 4.1019

# %% [markdown]
# ## Plot the results

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
